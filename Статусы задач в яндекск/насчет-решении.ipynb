# %% [markdown]
# ##### Мое решение задач C и F из модуля 4.2 яндекс не принял, долго возился но не смог предоставить нужное ему решение. А задачу J из того же модуля я попросту не смог решить. Из модуля 4.3 яндекс также не принял мое решение задачи I.
